# %% [markdown]
# # Figure Name
# Here we describe the figure created in this notebook.

# %% [markdown]
# First, we import our loader module.

# %%
from load_data import *

# %% [markdown]
# Next, load the data.

# %%
data = load_from_file()
data.head()
# Out:
#               A    B    C
# 01/09/2000  118  164  180
# 02/01/2000  115  149  156
# 02/01/2000  105  117  177
# 02/13/2000  130  110  102
# 02/14/2000  142  173  100

# %% [markdown]
# Then, proceed with your analysis. Here, we will show a plot of one subject's blood pressure over time

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(20, 10))
x = data.index
y = data['A']
plt.plot(x, y)
plt.xticks(rotation = 90)
plt.show()
